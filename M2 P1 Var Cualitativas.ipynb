# %% [markdown]
# <img src = "img/ITQ.png"> <br>
#
# ### Cualitativas
#
#
# <img src = "img/Python.png"> <br>
#
#
# *Martin Rodriguez*

# %%
# Creación aleatoria de datos
import numpy as np
import random
random.seed(42)

# %%
nivel_estudios = []
nivel_estudios.extend(['Secundaria']*110)
nivel_estudios.extend(['Bachillerato']*172)
nivel_estudios.extend(['Grado']*145)
nivel_estudios.extend(['Master']*52)
nivel_estudios.extend(['Doctorado']*21)

nivel_estudios = np.random.permutation(nivel_estudios)

# %%
print(nivel_estudios)
# Out:
# ['Secundaria' 'Bachillerato' 'Bachillerato' 'Master' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Secundaria' 'Grado' 'Secundaria' 'Grado' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Grado' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Master' 'Master' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Secundaria' 'Master'
#  'Doctorado' 'Secundaria' 'Master' 'Secundaria' 'Master' 'Grado' 'Grado'
#  'Secundaria' 'Doctorado' 'Grado' 'Grado' 'Secundaria' 'Bachillerato'
#  'Grado' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Master'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Grado'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Doctorado' 'Grado' 'Bachillerato' 'Master' 'Grado'
#  'Secundaria' 'Bachillerato' 'Master' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Doctorado' 'Bachillerato'
#  'Secundaria' 'Master' 'Bachillerato' 'Master' 'Master' 'Bachillerato'
#  'Grado' 'Secundaria' 'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Grado'
#  'Grado' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Bachillerato'
#  'Secundaria' 'Master' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Doctorado'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Doctorado' 'Bachillerato' 'Bachillerato' 'Doctorado'
#  'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Master' 'Master' 'Master'
#  'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Doctorado' 'Master' 'Grado' 'Secundaria' 'Grado'
#  'Bachillerato' 'Master' 'Grado' 'Bachillerato' 'Secundaria' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Secundaria' 'Master'
#  'Secundaria' 'Grado' 'Doctorado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Grado' 'Doctorado' 'Master' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Secundaria' 'Grado'
#  'Grado' 'Doctorado' 'Bachillerato' 'Grado' 'Secundaria' 'Doctorado'
#  'Grado' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Grado'
#  'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Grado' 'Master' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato'
#  'Master' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Doctorado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Master' 'Grado' 'Grado' 'Master' 'Secundaria'
#  'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Master' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Secundaria' 'Grado'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Secundaria' 'Bachillerato'
#  'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Secundaria' 'Master' 'Grado' 'Secundaria'
#  'Secundaria' 'Master' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado'
#  'Grado' 'Bachillerato' 'Secundaria' 'Secundaria' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Master' 'Secundaria' 'Secundaria'
#  'Secundaria' 'Master' 'Master' 'Grado' 'Bachillerato' 'Secundaria'
#  'Master' 'Bachillerato' 'Grado' 'Doctorado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Master' 'Secundaria' 'Bachillerato'
#  'Grado' 'Grado' 'Master' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Secundaria'
#  'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Doctorado' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Secundaria' 'Grado' 'Grado' 'Master'
#  'Master' 'Bachillerato' 'Doctorado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Master' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Master' 'Bachillerato' 'Secundaria' 'Grado' 'Secundaria' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Doctorado' 'Grado' 'Secundaria'
#  'Secundaria' 'Master' 'Grado' 'Secundaria' 'Grado' 'Grado' 'Grado'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Master' 'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Doctorado' 'Grado'
#  'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Master' 'Grado'
#  'Bachillerato' 'Secundaria' 'Grado' 'Master' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Master' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Secundaria' 'Grado'
#  'Master' 'Grado' 'Bachillerato' 'Master' 'Secundaria' 'Bachillerato'
#  'Grado' 'Master' 'Bachillerato' 'Master' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria' 'Doctorado' 'Master'
#  'Secundaria' 'Secundaria' 'Master' 'Grado' 'Doctorado' 'Grado' 'Grado'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria' 'Grado'
#  'Secundaria' 'Bachillerato' 'Grado' 'Master' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Master' 'Secundaria' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Grado'
#  'Secundaria' 'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Doctorado' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Master' 'Secundaria' 'Bachillerato']

# %%
# DIAGRAMA DE BARRAS
import matplotlib.pyplot as plt
import numpy as np
estudios, frecuencia = np.unique(nivel_estudios, return_counts=True)
print(estudios, frecuencia)
# Out:
# ['Bachillerato' 'Doctorado' 'Grado' 'Master' 'Secundaria'] [172  21 145  52 110]

# %%
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.bar(estudios, frecuencia) # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
plt.show()

# %%
# DIAGRAMA DE SECTORES
colores = {'red', 'blue', 'orange', 'green', 'cyan'}
plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.2f%%')
plt.title('Diagrama de sectores')
plt.show()

# %%
# Tarea implementar con pandas esta información 
import pandas as pd
#Genero el dataframe con los valores que ya estaba en el ejercicio, de la lista "nivel_estudios"
df = pd.DataFrame(nivel_estudios)

# Frecuencias
frecuencia = df.value_counts()

frecuencia.plot(
    kind = "bar", # tipo de gráfico
    title = "Nivel de Educación", #título del gráfico
    xlabel = "Nivel de Estudios", #etiqueta x
    ylabel = "Personas registradas" #etiqueta y
)
# Out:
# <Axes: title={'center': 'Nivel de Educación'}, xlabel='Nivel de Estudios', ylabel='Personas registradas'>
